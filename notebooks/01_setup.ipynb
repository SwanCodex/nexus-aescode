# %% [markdown]
# # 1 - SETUP

# %%
import os

folders = [
    "data/raw", "data/processed", "data/features", "data/splits",
    "models/tcn", "models/tft", "models/xgboost", "models/ensemble",
    "outputs/metrics", "outputs/plots", "outputs/shap", "outputs/logs",
    "src/models", "src/losses", "src/utils"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Project structure created.")
# Out:
# Project structure created.

# %%
import torch

print("CUDA Available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# CUDA Available: False
# GPU: None

# %%
import random
import numpy as np
import torch

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

set_seed()

# %%
CONFIG = {
    "batch_size": 64,
    "lr": 1e-3,
    "weight_decay": 1e-4,
    "epochs": 50,
    "patience": 10,
    "sequence_length": 6,
    "num_features": 22,
    "hidden_dim": 64,
    "dropout": 0.3,
    "focal_alpha": 0.25,
    "focal_gamma": 2,
}
